# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/src/task1_ingestion

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/src/task2_enriched_dims

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/src/task3_enriched_orders

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/src/task4_enriched_profit

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/resources/utils

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/tests/test_task1_ingestion

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/tests/test_task2_enriched_dims

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/tests/test_task3_enriched_orders

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/tests/test_task4_enriched_profit

# %%
# %run /Workspace/Users/ashutoshp2@icloud.com/ecommerce_data_pipeline/tests/test_task5_profit_metrics

# %%
logger = get_logger()

# %%
def main_pipeline():
    try:
        # Run ingestion test, then ingestion src
        main_ingestion_test()
        logger.info("Ingestion tests executed successfully.")
        main_ingestion()
        logger.info("Ingestion step executed successfully.")

        # Run dims test, then dims src
        main_dims_test()
        logger.info("Dimension tests executed successfully.")
        main_build_dims()
        logger.info("Dimension step executed successfully.")

        # Run orders test, then orders src
        main_orders_test()
        logger.info("Orders tests executed successfully.")
        main_build_orders()
        main_build_enriched_orders()
        logger.info("Orders step executed successfully.")

        # Run enriched profit test, then enriched profit src
        main_enriched_profit_test()
        logger.info("Enrichment tests executed successfully.")
        main_enrich()
        logger.info("Enrichment step executed successfully.")

        # Run profit metrics test, then profit metrics src
        main_profit_metrics_test()
        logger.info("Profit metrics tests executed successfully.")

        logger.info("Pipeline executed successfully.")
    except Exception as e:
        logger.error(f"Pipeline execution failed: {e}")
        raise

if __name__ == "__main__":
    main_pipeline()
